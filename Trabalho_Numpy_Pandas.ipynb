# %% [markdown]
# <a href="https://colab.research.google.com/github/miguel-filho/Agente-Reativo-Baseado-em-Modelo/blob/master/Trabalho_Numpy_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 672680242082939004, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6781068043792371424
#  physical_device_desc: "device: XLA_CPU device"]

# %%
# !pip install tensorflow

# %%
# !wget clone https://github.com/miguel-filho/Google-Colabe-Numpy-Pandas.git
# Out:
# --2019-06-03 17:42:58--  http://clone/
# Resolving clone (clone)... failed: Name or service not known.
# wget: unable to resolve host address ‘clone’
# --2019-06-03 17:42:58--  https://github.com/miguel-filho/Google-Colabe-Numpy-Pandas.git
# Resolving github.com (github.com)... 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/miguel-filho/Google-Colabe-Numpy-Pandas [following]
# --2019-06-03 17:42:58--  https://github.com/miguel-filho/Google-Colabe-Numpy-Pandas
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Google-Colabe-Numpy-Pandas.git’
#
# Google-Colabe-Numpy     [ <=>                ]  69.03K  --.-KB/s    in 0.05s
#
# 2019-06-03 17:42:58 (1.32 MB/s) - ‘Google-Colabe-Numpy-Pandas.git’ saved [70688]
#
# FINISHED --2019-06-03 17:42:58--
# ...

# %%
# !ls
# Out:
# Google-Colabe-Numpy-Pandas.git	sample_data

# %%
# %cd ../
# Out:
# /

# %%
# !ls
# Out:
# bin	 datalab  home	 lib64	opt   run   swift		tmp    var
# boot	 dev	  lib	 media	proc  sbin  sys			tools
# content  etc	  lib32  mnt	root  srv   tensorflow-2.0.0a0	usr

# %%
cd content
# Out:
# /content

# %%
# !ls
# Out:
# Google-Colabe-Numpy-Pandas.git	sample_data

# %%
cd sample_data
# Out:
# /content/sample_data

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !rm mnist_test.csv

# %%
# !ls
# Out:
# anscombe.json		     california_housing_train.csv  README.md
# california_housing_test.csv  mnist_train_small.csv

# %%
# !cat 'README.md'
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %%
from google.colab import files
import pandas as pd

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6483d4bf-6f89-4961-80fa-34589d5b6487" name="files[]" multiple disabled />
#      <output id="result-6483d4bf-6f89-4961-80fa-34589d5b6487">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
pd.read_csv('train.csv')
# Out:
#      PassengerId  Survived  Pclass  ...      Fare        Cabin  Embarked
# 0              1         0       3  ...    7.2500          NaN         S
# 1              2         1       1  ...   71.2833          C85         C
# 2              3         1       3  ...    7.9250          NaN         S
# 3              4         1       1  ...   53.1000         C123         S
# 4              5         0       3  ...    8.0500          NaN         S
# 5              6         0       3  ...    8.4583          NaN         Q
# 6              7         0       1  ...   51.8625          E46         S
# 7              8         0       3  ...   21.0750          NaN         S
# 8              9         1       3  ...   11.1333          NaN         S
# 9             10         1       2  ...   30.0708          NaN         C
# 10            11         1       3  ...   16.7000           G6         S
# 11            12         1       1  ...   26.5500         C103         S
# ...
